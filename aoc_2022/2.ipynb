# %%
import numpy as np

def winning(opp,me):
    #lose
    if opp == "A" and me == "Z" or opp == "B" and me == "X" or opp == "C" and me == "Y":
        return 0
    #win
    elif opp == "A" and me == "Y" or opp == "B" and me == "Z" or opp == "C" and me == "X":
        return 6
    #draw
    else:
        return 3

def map_to_val(x):
    if x == "A" or x == "X": 
        return 0
    elif x == "B" or x == "Y": 
        return 1
    else: 
        return 2,

data = []
with open("2.txt") as f:
    for line in f:
        arr = line.strip("\n").split(" ")
        for elem in arr:
            elem = map_to_val(elem)
            print(elem)

score = 0
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
